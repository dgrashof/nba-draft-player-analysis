# %% [markdown]
# ## 1. Preliminary Modeling - Predicting NBA Steals + Blocks

# %% [markdown]
# ### 1.1 Load Data

# %%
import pandas as pd
import numpy as np
import os
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,StackingRegressor
import seaborn as sns
from scipy.stats import beta as bt
import matplotlib.pyplot as  plt
import warnings
warnings.filterwarnings('ignore')

os.chdir('C:\\Users\\David\\OneDrive')
from utils.ml_data_proc import tts
from utils.graphs import corrtest,normality_test,regression_results,plot_scatter
os.chdir('C:\\Users\\David\\OneDrive\\Projects\\nba-draft-player-analysis')

#read college data
df = pd.read_csv('data/modeling_data.csv')
df = df[df['nba_minutes_played']>1000]

# %% [markdown]
# ### 1.2 Steals

# %% [markdown]
# #### Steals per 40 (NBA)

# %%
df['nba_steals_per_40'].hist()
plt.title('NBA Steals per 40 Dist')
# Out:
# Text(0.5, 1.0, 'NBA Steals per 40 Dist')

# %%
normality_test(np.log(df['nba_steals_per_40']))
# Out:
# P-value of 0.024 is not greater than .05 and does not meet normality criteria

# %% [markdown]
# #### Steals per 40 (College)

# %%
df['steals_per_40'].hist()
plt.title('College Career Steals per 40')
# Out:
# Text(0.5, 1.0, 'College Career Steals per 40')

# %%
normality_test(np.log(df['steals_per_40']))
# Out:
# P-value of 0.0 is not greater than .05 and does not meet normality criteria

# %% [markdown]
# #### Blocks per 40 (College)

# %%
df['nba_blocks_per_40'].hist()
plt.title('NBA Blocks per 40 Dist')
# Out:
# Text(0.5, 1.0, 'NBA Blocks per 40 Dist')

# %%
normality_test(df['steals_per_40'])
# Out:
# P-value of 0.0 is not greater than .05 and does not meet normality criteria

# %%
normality_test(np.log(df['steals_per_40']))
# Out:
# P-value of 0.0 is not greater than .05 and does not meet normality criteria

# %% [markdown]
# ### 1.3 Create Regression - Steals

# %%
#create feature to proxy for usage rates
df['usg_per_40'] = df['two_pointers_per_40']+df['three_point_attempts_per_40']+df['free_throw_attempts_per_40']


cont_fields = ['steals_per_40','usg_per_40','personal_fouls_per_40']
cat_fields = ['yrs_played']

response = 'nba_steals_per_40'


Xtrain,Xtest,ytrain,ytest = tts(df,cat_fields,cont_fields,response)

# %% [markdown]
# #### 1.3.1 Linear Regression

# %%
model1 = LinearRegression()
model1.fit(Xtrain,ytrain)
y_predict = model1.predict(Xtest)
regression_results(y_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.069
# Explained Variance: 0.644
# R^2 Score:          0.644

# %%
pd.DataFrame({'Feature':Xtrain.columns,'Coefficients':model1.coef_}).sort_values(by='Coefficients',ascending=False)
# Out:
#                  Feature  Coefficients
# 5          steals_per_40      0.338302
# 4           yrs_played_5      0.109365
# 2           yrs_played_3     -0.016909
# 7  personal_fouls_per_40     -0.020342
# 3           yrs_played_4     -0.022259
# 0           yrs_played_1     -0.032348
# 1           yrs_played_2     -0.037850
# 6             usg_per_40     -0.079931

# %%
results = pd.DataFrame({'Actual':ytest,'Predict':y_predict},index=ytest.index)
results = pd.merge(left=results,right=df['col_lkup'],left_index=True,right_index=True,how='left')
results.sort_values(by='Predict',ascending=False).head(10)
# Out:
#      Actual   Predict                          col_lkup
# 276    2.70  2.524447           Eric Murdock providence
# 558    2.16  2.384192             Mario Chalmers kansas
# 80     2.00  2.312309            Bonzi Wells ball-state
# 627    2.52  2.256720  Orien Greene louisiana-lafayette
# 553    2.06  2.191678       Marcus Smart oklahoma-state
# 346    2.33  2.153673         Jamaal Tinsley iowa-state
# 503    1.82  2.089447             Laron Profit maryland
# 466    2.18  2.046058             Kenny Battle illinois
# 736    1.90  2.033560     Shawn Marion nevada-las-vegas
# 327    2.04  1.983851        Iman Shumpert georgia-tech

# %% [markdown]
# #### 1.3.2 Random Forest Regression

# %%
model2 = RandomForestRegressor()
model2.fit(Xtrain,ytrain)
y_predict = model2.predict(Xtest)
regression_results(y_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.074
# Explained Variance: 0.618
# R^2 Score:          0.618

# %%
pd.DataFrame({'Feature':Xtrain.columns,'Coefficients':model2.feature_importances_}).sort_values(by='Coefficients',ascending=False)

# %%
results = pd.DataFrame({'Actual':ytest,'Predict':y_predict},index=ytest.index)
results = pd.merge(left=results,right=df['col_lkup'],left_index=True,right_index=True,how='left')
results.sort_values(by='Predict',ascending=False).sample(10)
# Out:
#      Actual  Predict                          col_lkup
# 443    0.88   0.8689            Julius Randle kentucky
# 416    1.59   1.1902              John Crotty virginia
# 151    1.84   1.4722              Chuck Hayes kentucky
# 332    1.35   1.1508          Isaiah Thomas washington
# 112    1.70   1.4315        Cameron Payne murray-state
# 199    0.96   1.3110                 David West xavier
# 79     1.47   1.3569              Bobby Simmons depaul
# 569    0.78   0.8875         Marreese Speights florida
# 339    1.95   1.8003             Jae Crowder marquette
# 764    1.52   1.2980  Tariq Abdul-Wahad san-jose-state

# %% [markdown]
# #### 1.3.3 SVR

# %%
model3 = SVR()
model3.fit(Xtrain,ytrain)
y_predict = model3.predict(Xtest)
regression_results(y_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.075
# Explained Variance: 0.615
# R^2 Score:          0.615

# %%
results = pd.DataFrame({'Actual':ytest,'Predict':y_predict},index=ytest.index)
results = pd.merge(left=results,right=df['col_lkup'],left_index=True,right_index=True,how='left')
results.sort_values(by='Predict',ascending=False).head(10)
# Out:
#      Actual   Predict                          col_lkup
# 627    2.52  2.326384  Orien Greene louisiana-lafayette
# 466    2.18  2.176860             Kenny Battle illinois
# 346    2.33  2.163359         Jamaal Tinsley iowa-state
# 469    1.83  2.090183        Kent Bazemore old-dominion
# 327    2.04  2.082392        Iman Shumpert georgia-tech
# 228    1.43  2.076076             Dion Waiters syracuse
# 297    2.20  2.069962       George Lynch north-carolina
# 100    2.03  2.026897    Brooks Thompson oklahoma-state
# 693    2.22  2.013203            Ronnie Brewer arkansas
# 558    2.16  1.999546             Mario Chalmers kansas

# %% [markdown]
# #### 1.3.4 Stacking Regressor

# %%
#embed models in Classifier and use Logistic Regression as Final Estimator
stacking_model = StackingRegressor(
    estimators=[("lr",model1),("rf",model2),("svr",model3)],final_estimator = LinearRegression())

stacking_model.fit(Xtrain,ytrain)
stacking_model_predict = stacking_model.predict(Xtest)
regression_results(stacking_model_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.067
# Explained Variance: 0.656
# R^2 Score:          0.656

# %%
results = pd.DataFrame({'Actual':ytest,'Predict':stacking_model_predict},index=ytest.index)
results = pd.merge(left=results,right=df['col_lkup'],left_index=True,right_index=True,how='left')
results['diff'] = np.abs(results['Actual']-results['Predict'])
results.sort_values(by='diff',ascending=False).head(10)
# Out:
#      Actual   Predict                          col_lkup      diff
# 161    2.09  1.219700           Cory Alexander virginia  0.870300
# 240    2.47  1.765495          Doug Christie pepperdine  0.704505
# 204    1.79  1.128001         DeMarcus Cousins kentucky  0.661999
# 678    2.20  1.559502  Robert Covington tennessee-state  0.640498
# 639    1.98  1.370602                Paul Pierce kansas  0.609398
# 647    0.77  1.356871                   Quinn Cook duke  0.586871
# 228    1.43  1.995394             Dion Waiters syracuse  0.565394
# 563    0.76  1.310643                Mark Pope kentucky  0.550643
# 355    0.87  1.419540              James Jones miami-fl  0.549540
# 666    2.42  1.905506    Reggie Jordan new-mexico-state  0.514494

# %% [markdown]
# ### 1.4  Create Regression - Blocks

# %% [markdown]
# #### 1.4.1 Linear Regression

# %%
cont_fields = ['blocks_per_40','personal_fouls_per_40','height']
cat_fields = ['yrs_played']

response = 'nba_blocks_per_40'


Xtrain,Xtest,ytrain,ytest = tts(df,cat_fields,cont_fields,response)

# %%
model1 = LinearRegression()
model1.fit(Xtrain,ytrain)
y_predict = model1.predict(Xtest)
regression_results(y_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.137
# Explained Variance: 0.748
# R^2 Score:          0.746

# %%
pd.DataFrame({'Feature':Xtrain.columns,'Coefficients':model1.coef_}).sort_values(by='Coefficients',ascending=False)
# Out:
#                  Feature  Coefficients
# 5          blocks_per_40      0.651174
# 7                 height      0.057701
# 2           yrs_played_3      0.033982
# 3           yrs_played_4      0.020405
# 6  personal_fouls_per_40      0.018321
# 1           yrs_played_2      0.014196
# 0           yrs_played_1      0.006721
# 4           yrs_played_5     -0.075304

# %%
results = pd.DataFrame({'Actual':ytest,'Predict':y_predict},index=ytest.index)
results = pd.merge(left=results,right=df['col_lkup'],left_index=True,right_index=True,how='left')
results.sort_values(by='Predict',ascending=False).sample(10)
# Out:
#      Actual   Predict                        col_lkup
# 801    0.56  0.477366               Trevor Ariza ucla
# 730    0.20  0.085472           Shane Larkin miami-fl
# 404    0.57  0.509511          Jimmy Butler marquette
# 384    1.22  0.804497     Jayson Williams st-johns-ny
# 572    1.63  1.356355              Mason Plumlee duke
# 99     1.94  1.672586            Brook Lopez stanford
# 765    0.22  0.299742         Tate George connecticut
# 396    0.28  0.271531  Jermaine Jackson detroit-mercy
# 23     0.39  0.355477        Alvin Williams villanova
# 430    0.69  0.550883           Jordan Hamilton texas

# %% [markdown]
# #### 1.4.2 Random Forest Regression

# %%
model2 = RandomForestRegressor()
model2.fit(Xtrain,ytrain)
y_predict = model2.predict(Xtest)
regression_results(y_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.139
# Explained Variance: 0.744
# R^2 Score:          0.742

# %%
pd.DataFrame({'Feature':Xtrain.columns,'Coefficients':model2.feature_importances_}).sort_values(by='Coefficients',ascending=False)
# Out:
#                  Feature  Coefficients
# 5          blocks_per_40      0.871329
# 6  personal_fouls_per_40      0.063546
# 7                 height      0.038565
# 3           yrs_played_4      0.007137
# 2           yrs_played_3      0.007055
# 0           yrs_played_1      0.006749
# 1           yrs_played_2      0.005578
# 4           yrs_played_5      0.000043

# %% [markdown]
# #### 1.4.3 SVR

# %%
model3 = SVR()
model3.fit(Xtrain,ytrain)
y_predict = model3.predict(Xtest)
regression_results(y_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.133
# Explained Variance: 0.759
# R^2 Score:          0.753

# %% [markdown]
# #### 1.4.4 Stacking Regressor

# %%
#embed models in Classifier and use Logistic Regression as Final Estimator
stacking_model = StackingRegressor(
    estimators=[("lr",model1),("rf",model2),("svr",model3)],final_estimator = LinearRegression())

stacking_model.fit(Xtrain,ytrain)
stacking_model_predict = stacking_model.predict(Xtest)
regression_results(stacking_model_predict,ytest)
# Out:
# Model Results
# -----------------------------------------------
# MSE:                 0.132
# Explained Variance: 0.758
# R^2 Score:          0.756

# %%
results = pd.DataFrame({'Actual':ytest,'Predict':stacking_model_predict},index=ytest.index)
results = pd.merge(left=results,right=df['col_lkup'],left_index=True,right_index=True,how='left')
results['diff'] = np.abs(results['Actual']-results['Predict'])
results.sort_values(by='diff',ascending=False).head(10)
# Out:
#      Actual   Predict                             col_lkup      diff
# 649    3.19  1.048817                 Raef LaFrentz kansas  2.141183
# 468    2.28  0.311456               Kenny Williams gonzaga  1.968544
# 695    3.31  1.359532                 Ronny Turiaf gonzaga  1.950468
# 760    3.63  1.975657                 Steven Hunter depaul  1.654343
# 508    3.86  2.674510  Larry Sanders virginia-commonwealth  1.185490
# 750    2.82  1.786751      Stanley Roberts louisiana-state  1.033249
# 412    3.67  2.870248             Joel Przybilla minnesota  0.799752
# 70     2.04  1.245484                   Bison Dele arizona  0.794516
# 451    1.73  2.488575          Karl-Anthony Towns kentucky  0.758575
# 270    2.28  2.998999             Emeka Okafor connecticut  0.718999
